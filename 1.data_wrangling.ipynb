# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('./data/train.csv')

# %%
test = pd.read_csv('./data/test.csv')

# %%
print(train.shape, test.shape)
# Out:
# (188318, 132) (125546, 131)

# %%
display(train.describe())
# Out:
#                   id          cont1          cont2          cont3  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean   294135.982561       0.493861       0.507188       0.498918
# std    169336.084867       0.187640       0.207202       0.202105
# min         1.000000       0.000016       0.001149       0.002634
# 25%    147748.250000       0.346090       0.358319       0.336963
# 50%    294539.500000       0.475784       0.555782       0.527991
# 75%    440680.500000       0.623912       0.681761       0.634224
# max    587633.000000       0.984975       0.862654       0.944251
#
#                cont4          cont5          cont6          cont7  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.491812       0.487428       0.490945       0.484970
# std         0.211292       0.209027       0.205273       0.178450
# min         0.176921       0.281143       0.012683       0.069503
# 25%         0.327354       0.281143       0.336105       0.350175
# 50%         0.452887       0.422268       0.440945       0.438285
# 75%         0.652072       0.643315       0.655021       0.591045
# max         0.954297       0.983674       0.997162       1.000000
#
#                cont8          cont9         cont10         cont11  \
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.486437       0.485506       0.498066       0.493511
# std         0.199370       0.181660       0.185877       0.209737
# min         0.236880       0.000080       0.000000       0.035321
# 25%         0.312800       0.358970       0.364580       0.310961
# 50%         0.441060       0.441450       0.461190       0.457203
# 75%         0.623580       0.566820       0.614590       0.678924
# max         0.980200       0.995400       0.994980       0.998742
#
#               cont12         cont13         cont14           loss
# count  188318.000000  188318.000000  188318.000000  188318.000000
# mean        0.493150       0.493138       0.495717    3037.337686
# std         0.209427       0.212777       0.222488    2904.086186
# min         0.036232       0.000228       0.179722       0.670000
# 25%         0.311661       0.315758       0.294610    1204.460000
# 50%         0.462286       0.363547       0.407403    2115.570000
# 75%         0.675759       0.689974       0.724623    3864.045000
# max         0.998484       0.988494       0.844848  121012.250000

# %%
display(test.describe())
# Out:
#                   id          cont1          cont2          cont3  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean   294067.153442       0.494447       0.506939       0.498255
# std    170098.335649       0.187961       0.206837       0.201746
# min         4.000000       0.000016       0.001149       0.002634
# 25%    146414.250000       0.347403       0.358319       0.336963
# 50%    294306.000000       0.475784       0.555782       0.527991
# 75%    441800.000000       0.626630       0.681761       0.634224
# max    587634.000000       0.984975       0.862654       0.944251
#
#                cont4          cont5          cont6          cont7  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean        0.492334       0.487640       0.492188       0.485945
# std         0.210815       0.209119       0.205574       0.178650
# min         0.176921       0.281143       0.012683       0.069503
# 25%         0.327354       0.281143       0.336105       0.352087
# 50%         0.452887       0.422268       0.441525       0.438893
# 75%         0.652072       0.643315       0.659261       0.591284
# max         0.956046       0.983107       0.997162       1.000000
#
#                cont8          cont9         cont10         cont11  \
# count  125546.000000  125546.000000  125546.000000  125546.000000
# mean        0.487401       0.486015       0.498909       0.494360
# std         0.199549       0.182134       0.185950       0.210399
# min         0.236880       0.000080       0.000000       0.035321
# 25%         0.317960       0.358970       0.364580       0.310961
# 50%         0.441060       0.441450       0.466720       0.457203
# 75%         0.629180       0.568890       0.619840       0.678924
# max         0.982800       0.995400       0.994980       0.997830
#
#               cont12         cont13         cont14
# count  125546.000000  125546.000000  125546.000000
# mean        0.494033       0.495086       0.495586
# std         0.210148       0.213108       0.222613
# min         0.036232       0.000228       0.178568
# 25%         0.318249       0.315758       0.294752
# 50%         0.462286       0.363547       0.406104
# 75%         0.682413       0.689974       0.724791
# max         0.997416       0.988494       0.844814

# %%
train_cat = train.select_dtypes(exclude=['float64']).set_index('id')
sum(train_cat.isnull().sum())
# Out:
# 0

# %%
test_cat = test.select_dtypes(exclude=['float64']).set_index('id')
sum(test_cat.isnull().sum())
# Out:
# 0

# %%
train_cat.describe(include=['O'])
# Out:
#           cat1    cat2    cat3    cat4    cat5    cat6    cat7    cat8  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    141550  106721  177993  128395  123737  131693  183744  177274
#
#           cat9   cat10   cat11   cat12   cat13   cat14   cat15   cat16  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    113122  160213  168186  159825  168851  186041  188284  181843
#
#          cat17   cat18   cat19   cat20   cat21   cat22   cat23   cat24  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    187009  187331  186510  188114  187905  188275  157445  181977
#
#          cat25   cat26   cat27   cat28   cat29   cat30   cat31   cat32  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    169969  177119  168250  180938  184593  184760  182980  187107
#
#          cat33   cat34   cat35   cat36   cat37   cat38   cat39   cat40  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    187361  187734  188105  156313  165729  169323  183393  180119
#
#          cat41   cat42   cat43   cat44   cat45   cat46   cat47   cat48  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    181177  186623  184110  172716  183991  187436  187617  188049
#
#          cat49   cat50   cat51   cat52   cat53   cat54   cat55   cat56  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    179127  137611  187071  179505  172949  183762  188173  188136
#
#          cat57   cat58   cat59   cat60   cat61   cat62   cat63   cat64  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    185296  188079  188018  187872  187596  188273  188239  188271
#
#          cat65   cat66   cat67   cat68   cat69   cat70   cat71   cat72  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    186056  179982  187626  188176  188011  188295  178646  118322
#
#          cat73   cat74   cat75   cat76   cat77   cat78   cat79   cat80  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       3       3       3       3       4       4       4       4
# top          A       A       A       A       D       B       B       D
# freq    154275  184731  154307  181347  187503  186526  152929  137505
#
#          cat81   cat82   cat83   cat84   cat85   cat86   cat87   cat88  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       4       4       4       4       4       4       4       4
# top          D       B       B       C       B       B       B       A
# freq    154385  147536  141534  154939  186005  103852  166992  168926
#
#          cat89   cat90   cat91   cat92   cat93   cat94   cat95   cat96  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       8       7       8       7       5       7       5       8
# top          A       A       A       A       D       D       C       E
# freq    183744  177993  111028  124689  150237  121642   87531  174360
#
#          cat97   cat98   cat99  cat100  cat101  cat102  cat103  cat104  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique       7       5      16      15      19       9      13      17
# top          C       A       P       F       A       A       A       E
# freq     78127  105492   79455   42970  106721  177274  123737   42925
#
#         cat105  cat106  cat107  cat108  cat109  cat110  cat111  cat112  \
# count   188318  188318  188318  188318  188318  188318  188318  188318
# unique      20      17      20      11      84     131      16      51
# top          E       G       F       B      BI      CL       A       E
# freq     76493   47165   47310   65512  152918   25305  128395   25148
#
#         cat113  cat114  cat115  cat116
# count   188318  188318  188318  188318
# unique      61      19      23     326
# top         BM       A       K      HK
# freq     26191  131693   43866   21061

# %%
test.describe(include=['O'])
# Out:
#           cat1    cat2    cat3    cat4    cat5    cat6    cat7    cat8  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq     94096   71203  118752   86026   82282   88014  122546  118112
#
#           cat9   cat10   cat11   cat12   cat13   cat14   cat15   cat16  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq     75509  106944  112470  106777  112604  123954  125523  121262
#
#          cat17   cat18   cat19   cat20   cat21   cat22   cat23   cat24  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    124666  124902  124376  125434  125291  125519  105272  121430
#
#          cat25   cat26   cat27   cat28   cat29   cat30   cat31   cat32  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    113405  118077  112239  120751  123093  123247  122061  124723
#
#          cat33   cat34   cat35   cat36   cat37   cat38   cat39   cat40  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    124914  125184  125417  104035  110512  112774  122170  120081
#
#          cat41   cat42   cat43   cat44   cat45   cat46   cat47   cat48  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    120840  124343  122811  114985  122647  124972  125055  125366
#
#          cat49   cat50   cat51   cat52   cat53   cat54   cat55   cat56  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    119495   91888  124761  119761  115388  122577  125449  125435
#
#          cat57   cat58   cat59   cat60   cat61   cat62   cat63   cat64  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    123560  125393  125340  125289  125024  125525  125501  125524
#
#          cat65   cat66   cat67   cat68   cat69   cat70   cat71   cat72  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       2       2       2       2       2       2       2       2
# top          A       A       A       A       A       A       A       A
# freq    124021  119930  125112  125437  125351  125526  119187   79486
#
#          cat73   cat74   cat75   cat76   cat77   cat78   cat79   cat80  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       3       3       3       3       4       4       4       4
# top          A       A       A       A       D       B       B       D
# freq    102595  123055  102828  120866  124976  124325  102007   91839
#
#          cat81   cat82   cat83   cat84   cat85   cat86   cat87   cat88  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       4       4       4       4       4       4       4       4
# top          D       B       B       C       B       B       B       A
# freq    102914   98004   94109  103199  123963   68647  111306  112427
#
#          cat89   cat90   cat91   cat92   cat93   cat94   cat95   cat96  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       8       6       8       8       5       7       5       9
# top          A       A       A       A       D       D       C       E
# freq    122546  118752   73787   83053  100031   80907   58836  116162
#
#          cat97   cat98   cat99  cat100  cat101  cat102  cat103  cat104  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique       7       5      17      15      17       7      14      17
# top          C       A       P       F       A       A       A       E
# freq     51813   69800   52645   28847   71203  118112   82282   28632
#
#         cat105  cat106  cat107  cat108  cat109  cat110  cat111  cat112  \
# count   125546  125546  125546  125546  125546  125546  125546  125546
# unique      18      18      20      11      74     123      16      51
# top          E       G       F       B      BI      CL       A       E
# freq     50984   31015   31553   43219  102134   16792   86026   16961
#
#         cat113  cat114  cat115  cat116
# count   125546  125546  125546  125546
# unique      60      18      23     311
# top         BM       A       K      HK
# freq     17565   88014   29161   14015
